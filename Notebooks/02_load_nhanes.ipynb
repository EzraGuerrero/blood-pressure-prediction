# %%
import os
import requests
import pandas as pd

# Create folders
os.makedirs("../data/raw", exist_ok=True)
os.makedirs("../data/processed", exist_ok=True)

# NHANES 2021-2023 URLs
urls = {
    "demo": "https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/DEMO_L.xpt",
    "bpx": "https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/BPXO_L.xpt",
    "bmx": "https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/BMX_L.xpt"
}

# Download Files
for name, url in urls.items():
    print(f"Downloading: {name}...")
    response = requests.get(url)
    file_path = f"../data/raw/{name}_L.xpt"
    with open (f"../data/raw/{name}_L.xpt", "wb") as f:
        f.write(response.content)
    print(f"{name}_L.xpt downloaded")

    # Read .xpt and save as CSV
    df = pd.read_sas(file_path)
    csv_path = f"../data/processed/{name}_clean.csv"
    df.to_csv(csv_path, index=False)
    print(f"{name}_clean.csv saved\n")

print("All files downloaded and converted")
# Out:
# Downloading: demo...
# demo_L.xpt downloaded
# demo_clean.csv saved
#
# Downloading: bpx...
# bpx_L.xpt downloaded
# bpx_clean.csv saved
#
# Downloading: bmx...
# bmx_L.xpt downloaded
# bmx_clean.csv saved
#
# All files downloaded and converted
